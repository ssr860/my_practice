# %%
# 建立csv表格并正确读取金内存
import os 

os.makedirs(os.path.join('..','data'),exist_ok=True)
datafile = os.path.join('..','data','my.csv')
with open('datafile','w') as f:
    f.write('.....\n')

import pandas as pd

data = pd.read_csv(datafile)
print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
# ----> 3 os.makedis(os.path.join('..','data'),exist_ok=True)
#       4 datafile = os.path.join('..','data','my.csv')
#       5 with open('datafile','w') as f:
#
# AttributeError: module 'os' has no attribute 'makedis'

# %%
# 处理缺失值
inputs, outputs = data.iloc[:, 0:2], data.iloc[:, 2]
# iloc为位置索引
inputs = inputs.fillna(inputs.mean())
# 注意fillna语法
print(inputs) 

inputs = pd.get_dummies(inputs, dummy_na=True)
# 分为很多种情况，包括nan也是一种情况，根据所属关系生成one-hot值
print(inputs)

# %%
# 转换成张量

import torch

X, y = torch.tensor(inputs.values), torch.tensor(outputs.values)

X = torch.tensor(inputs.to_numpy(dtype = float))
